# %% [markdown]
# matplotlib - основная библиотека для визуализации
# https://matplotlib.org/
#
# seaborn - надстройка над matplotlib с более простым синтаксисом и лучшим качеством графиков
# https://seaborn.pydata.org/
#
# pandas
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %%
import pandas as pd
import numpy as np

# %%
# получать результаты визуализаций в юпитер-ноутбуке
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
# %config IPCompleter.greedy=True

# %%
students_performance = pd.read_csv('StudentsPerformance.csv')
students_performance.columns = [x.replace(" ", "_") for x in students_performance.columns]
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### pandas

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
students_performance.math_score.mean()
# Out:
# 66.089

# %%
students_performance.math_score.hist()

# %% [markdown]
# hist() - функция библиотеки matplotlib, интегрированная в pandas
# https://matplotlib.org/gallery/pyplots/pyplot_text.html#sphx-glr-gallery-pyplots-pyplot-text-py

# %%
students_performance.plot.scatter(x='math_score', y='reading_score')

# %% [markdown]
# ### seaborn
# https://seaborn.pydata.org/introduction.html
#
# https://seaborn.pydata.org/generated/seaborn.lmplot.html?highlight=seaborn%20lmplot#seaborn.lmplot

# %%
sns.lmplot(x='math_score', y='reading_score', data=students_performance)
# Out:
# C:\Users\siven\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# добавим группирующую переменную:

# %%
sns.lmplot(x='math_score', y='reading_score', hue='gender', data=students_performance)

# %% [markdown]
# без регрессионой прямой:

# %%
sns.lmplot(x='math_score', y='reading_score', hue='gender', data=students_performance, fit_reg = False)

# %% [markdown]
# кастомизация:

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data=students_performance, fit_reg = False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %% [markdown]
# # HW

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.plot()

# %%
df['income'].plot()

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
df.plot(kind='line')

# %%
df.income.plot()

# %%
plt.plot(df.index, df.income)

# %%
sns.lineplot(data=df)

# %%
data=pd.read_clipboard()

# %%
data.head()
# Out:
#             x           y
# 0  595.098001  306.393774
# 1  604.966555  291.477978
# 2  304.682625  908.616155
# 3  610.749008  292.517897
# 4  602.432711  296.387840

# %%
data.plot.scatter(x='x',y='y')
#students_performance.plot.scatter(x='math_score', y='reading_score')

# %%
ax = sns.lmplot(x='x', y='y',  data=data, fit_reg = False)
ax.set_xlabels('x')
ax.set_ylabels('y')

# %%
sns.scatterplot(data.iloc[:, 0], data.iloc[:, 1])

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv',header=0,index_col=0)

# %%
df
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g=sns.heatmap(df,cmap="viridis")

# %%
g=sns.heatmap(df,cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df_dota=pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv',header=0,index_col=0)

# %%
df_dota.head(20)
# Out:
#    attack_type  id  legs   localized_name                          name  \
# 0        Melee   1     2        Anti-Mage        npc_dota_hero_antimage
# 1        Melee   2     2              Axe             npc_dota_hero_axe
# 2       Ranged   3     4             Bane            npc_dota_hero_bane
# 3        Melee   4     2      Bloodseeker     npc_dota_hero_bloodseeker
# 4       Ranged   5     2   Crystal Maiden  npc_dota_hero_crystal_maiden
# 5       Ranged   6     2      Drow Ranger     npc_dota_hero_drow_ranger
# 6        Melee   7     2      Earthshaker     npc_dota_hero_earthshaker
# 7        Melee   8     2       Juggernaut      npc_dota_hero_juggernaut
# 8       Ranged   9     2           Mirana          npc_dota_hero_mirana
# 9       Ranged  10     0        Morphling       npc_dota_hero_morphling
# 10      Ranged  11     0     Shadow Fiend       npc_dota_hero_nevermore
# 11       Melee  12     2   Phantom Lancer  npc_dota_hero_phantom_lancer
# ...

# %%
s=([len(r.split(',')) for r in df_dota.roles])

df_dota['role_count']=s
df_dota.head()
df_dota.groupby('role_count')..count()
# Out:
#             attack_type  id  legs  localized_name  name  primary_attr  roles
# role_count
# 1                     1   1     1               1     1             1      1
# 2                     9   9     9               9     9             9      9
# 3                    28  28    28              28    28            28     28
# 4                    38  38    38              38    38            38     38
# 5                    33  33    33              33    33            33     33
# 6                     8   8     8               8     8             8      8

# %%
df_dota.roles.str.split(',').apply(len).mode()
# Out:
# 0    4
# dtype: int64

# %%
df_dota.roles.map(eval).map(len).mode()
# Out:
# 0    4
# dtype: int64

# %%
type(df_dota.roles.map(eval)[0])
# Out:
# list

# %%
a=str('1')
a=(eval(a))
a
# Out:
# 1

# %%
a='1+1'
eval(a)
# Out:
# 2

# %%
df_dota['roles'].agg(lambda x: len(x.split(','))).hist()

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv',index_col=0)

# %%
df.head()
#df=df.drop(columns='species')
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
for column in df:
    # Draw distribution with that column
    sns.distplot(df[column],kde_kws={ "label":column});

# %%
for column in df:
    sns.kdeplot(df[column])

# %%
df.iloc[:,0:5].apply(lambda x: sns.kdeplot(x))
# Out:
# sepal length    AxesSubplot(0.125,0.125;0.775x0.755)
# sepal width     AxesSubplot(0.125,0.125;0.775x0.755)
# petal_length    AxesSubplot(0.125,0.125;0.775x0.755)
# petal width     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df=df.rename(columns={'petal length':'petal_length'});
df.head(3)
a=sns.violinplot(y=df.petal_length)

# %%
a=sns.pairplot(df)

# %%
a=sns.pairplot(df, hue='species')

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
df.columns = [i.replace(' ','_') for i in df.columns]

# %%
#df.columns.apply(replace(' ','_') )

# %%
import sklearn
precision = sklearn.metrics.precision_score([15,30], [15,40],average='micro', zero_division=1)
recall = sklearn.metrics.precision_score([15,30], [15,40],average='macro')
F1= precision * recall * 2 / (precision + recall)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-290-8215e430e3a9> in <module>
#       1 import sklearn
# ----> 2 precision = sklearn.metrics.precision_score([15,30], [15,40],average='micro', zero_division=1)
#       3 recall = sklearn.metrics.precision_score([15,30], [15,40],average='macro')
#       4 F1= precision * recall * 2 / (precision + recall)
#
# AttributeError: module 'sklearn' has no attribute 'metrics'

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score

df=pd.read_csv('https://stepik.org/media/attachments/course/4852/songs.csv')

#df1=pd.read_csv('https://www.kaggle.com/gyani95/380000-lyrics-from-metrolyrics.csv')

# %%
df.head()
# Out:
#                    song  year          artist    genre  \
# 0            the-ownerz  2007       gangstarr  Hip-Hop
# 1  dead-sound-of-misery  2006  blind-guardian    Metal
# 2         modred-s-song  2006  blind-guardian    Metal
# 3        the-ninth-wave  2015  blind-guardian    Metal
# 4                skills  2014       gangstarr  Hip-Hop
#
#                                               lyrics  length  commas  \
# 0  "One-two.."\n"One-two, shots to the chin.. kno...    1300      24
# 1  It's dark\nLet's do it now\nBring in the siren...    1566       0
# 2  I've lost my battle before it starts\nmy first...     996       1
# 3  As dark night embraces\nWe are the nation\nI w...    2868       5
# 4  Skills, skills, skills\n"My Microphone"\n"It's...    3351      22
#
#    exclamations  colons  hyphens
# 0             5       0       11
# 1             0       0        0
# 2             0       1        0
# 3             0       0        0
# 4             0       0        3

# %%
X=df.drop(['artist'],axis=1)
y=df.artist
X = pd.get_dummies(X)
X.head()
# Out:
#    year  length  commas  exclamations  colons  hyphens  song_2-deep  \
# 0  2007    1300      24             5       0       11            0
# 1  2006    1566       0             0       0        0            0
# 2  2006     996       1             0       1        0            0
# 3  2015    2868       5             0       0        0            0
# 4  2014    3351      22             0       0        3            0
#
#    song_2-steps-ahead  song_a-dark-passage  song_above-the-clouds  ...  \
# 0                   0                    0                      0  ...
# 1                   0                    0                      0  ...
# 2                   0                    0                      0  ...
# 3                   0                    0                      0  ...
# 4                   0                    0                      0  ...
#
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf = tree.DecisionTreeClassifier(criterion='entropy')
clf.fit(X_train, y_train)
tree.plot_tree(clf, rounded=True, filled=True);

predictions = clf.predict(X_test)

precision = precision_score(y_test, predictions, average='micro')
precision
# Out:
# 1.0
