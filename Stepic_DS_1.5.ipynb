# %%
import pandas as pd
import numpy as np

# %%
students_performance=pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.loc [students_performance.gender=='female',['gender','lunch']].head(3)
# Out:
#    gender     lunch
# 0  female  standard
# 1  female  standard
# 2  female  standard

# %%
students_performance.gender.head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
students_performance['writing score'].head()
# Out:
# 0    74
# 1    88
# 2    93
# 3    44
# 4    75
# Name: writing score, dtype: int64

# %%
students_performance['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
mean_writing_score
# Out:
# 68.054

# %%
mean_writing_score=students_performance['writing score'].mean()

# %%
len(students_performance)
# Out:
# 1000

# %%
len(students_performance[students_performance['lunch']=='free/reduced'])
# Out:
# 355

# %%
students_performance.loc[students_performance['writing_score']>mean_writing_score].head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
True and False
# Out:
# False

# %%
students_performance.loc[(students_performance['writing score'] > 100 )&( students_performance.gender == 'female')]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
students_performance[:3]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
students_performance[['gender','lunch']][:3]
# Out:
#    gender     lunch
# 0  female  standard
# 1  female  standard
# 2  female  standard

# %%
students_performance['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
students_performance['gender'].plot()

# %%
students_performance.iloc[:3,:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree

# %%
students_performance['gender'][:3]
# Out:
# 0    female
# 1    female
# 2    female
# Name: gender, dtype: object

# %%
students_performance[['gender','lunch']][:3]
# Out:
#    gender     lunch
# 0  female  standard
# 1  female  standard
# 2  female  standard

# %%
students_performance.iloc[[1,2,3],[1,-1]]
# Out:
#   race/ethnicity  writing score
# 1        group C             88
# 2        group B             93
# 3        group A             44

# %%
    students_performance[students_performance['lunch']=='standard'].mean()
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
students_performance[students_performance['lunch']=='free/reduced'].mean()
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
students_performance[students_performance['lunch']=='standard'].var()
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %%
students_performance[students_performance['lunch']=='free/reduced'].var()
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
students_performance=students_performance\
.rename (columns={'writing score':'writing_score'}    )

# %%
students_performance.query("writing_score>74 | gender=='female'").head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
wr=78
students_performance.query("writing_score>@wr").head(1)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing_score
# 1               completed          69             90             88

# %%
student_stats=students_performance

# %%
student_stats.head(1)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test preparation course  math score  reading score  writing_score
# 0                    none          72             72             74

# %%
student_stats[student_stats['parental level of education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 32   female        group E             master's degree  free/reduced
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# 79   female        group E             master's degree      standard
# 90   female        group C           bachelor's degree      standard
# ...

# %%
student_stats[(student_stats['math score'] > 90) & (student_stats['reading score'] <=72)]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing_score]
# Index: []

# %%
score_columns=[i for i in list(students_performance) if 'score' in i]

# %%
students_performance.filter(like='score').head()
# Out:
#    math score  reading score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
students_performance.filter(regex='e$', like='e',axis=1).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-a22f216df319> in <module>
# ----> 1 students_performance.filter(regex='e$', like='e',axis=1).head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4558         nkw = com.count_not_none(items, like, regex)
#    4559         if nkw > 1:
# -> 4560             raise TypeError('Keyword arguments `items`, `like`, or `regex` '
#    4561                             'are mutually exclusive')
#    4562
#
# TypeError: Keyword arguments `items`, `like`, or `regex` are mutually exclusive

# %%
selected_columns=pd.read_csv('https://stepik.org/media/attachments/course/4852/column_hell.csv')

# %%
selected_columns.head(3)
# Out:
#       yrh&6      ohku         q      hfxx   umeca-4       apj         g  \
# 0  0.288397  0.911359  0.488069  0.074599  0.016124  0.090555  0.560810
# 1  0.861276  0.134987  0.701885  0.897921  0.507115  0.740151  0.963179
# 2  0.775577  0.832874  0.862665  0.831049  0.003274  0.703112  0.509795
#
#    ijvnixxo  kudbpyw-3    upubjv  ...        fi   clsruyy       g&6      qo$6  \
# 0  0.110975   0.430787  0.548763  ...  0.793122  0.070335  0.145115  0.686579
# 1  0.712024   0.671662  0.497596  ...  0.477181  0.767931  0.996055  0.948774
# 2  0.573296   0.286411  0.282792  ...  0.421542  0.770413  0.749468  0.395022
#
#          ap         o  sladymzr       tif   wuikzxt     wzuvc
# 0  0.071681  0.563068  0.815201  0.081902  0.333237  0.185148
# 1  0.054327  0.087341  0.072166  0.856081  0.120481  0.622113
# 2  0.307752  0.535575  0.341393  0.971201  0.714558  0.702453
#
# [3 rows x 75 columns]

# %%
selected_columns.filter(like='-').head(2)
# Out:
#     umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0  0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1  0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
